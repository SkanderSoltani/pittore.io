# %%
from PIL import Image
import cv2
import numpy as np
import tensorflow as tf

# %%
# Loading content and style images
content_image = Image.open("sanJuan\original\content4.jpg")
style_image   = Image.open("sanJuan\original\style4.jpg")

# Display images content and style images side by side
Image.fromarray(cv2.hconcat([np.array(content_image.resize((400,300))),np.array(style_image.resize((400,300)))]))
# Out:
# <PIL.Image.Image image mode=RGB size=800x300 at 0x168012FD408>

# %%
# %%capture
# import pittore from NeuralStyleTransfer.py
from NeuralStyleTransfer import pittore

# Create a pittore class
artista=pittore()

# run creareArte
art_list = art.creareArte(IMAGE_CONTENT=content_image,IMAGE_STYLE=style_image,epochs=300,verbose=False)

# %%
art_list[-1]
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x168380F4A88>
